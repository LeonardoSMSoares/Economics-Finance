# %% [markdown]
# # Chapter 15 Exercises

# %%
import datetime

import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import Model, Sequential

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError

from tensorflow.keras.layers import Dense, Conv1D, LSTM, Lambda, Reshape, RNN, LSTMCell

import warnings
warnings.filterwarnings('ignore')

# %%
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['axes.grid'] = False

# %%
tf.random.set_seed(42)
np.random.seed(42)

# %% [markdown]
# In the last chapter, we built linear models and deep neural networks to forecast the air
# quality. Now we’ll try LSTM models and see if there is a gain in performance.
#
# 1 For the single-step model:
#
#     a Build an LSTM model.
#     b Plot its predictions.
#     c Evaluate it using the MAE and store the MAE.
#     d Is it the most performant model?
#
# 2 For the multi-step model:
#
#     a Build an LSTM model.
#     b Plot its predictions.
#     c Evaluate it using the MAE and store the MAE.
#     d Is it the most performant model?
#
# 3 For the multi-output model:
#
#     a Build an LSTM model.
#     b Plot its predictions.
#     c Evaluate it using the MAE and store the MAE.
#     d Is it the most performant model?

# %%
train_df = pd.read_csv('data/ex_train.csv')
val_df = pd.read_csv('data/ex_val.csv')
test_df = pd.read_csv('data/ex_test.csv')

print(train_df.shape, val_df.shape, test_df.shape)
# Out:
# (13239, 12) (3783, 12) (1892, 12)

# %%
class DataWindow():
    def __init__(self, input_width, label_width, shift, 
                 train_df=train_df, val_df=val_df, test_df=test_df, 
                 label_columns=None):
        
        self.train_df = train_df
        self.val_df = val_df
        self.test_df = test_df
        
        self.label_columns = label_columns
        if label_columns is not None:
            self.label_columns_indices = {name: i for i, name in enumerate(label_columns)}
        self.column_indices = {name: i for i, name in enumerate(train_df.columns)}
        
        self.input_width = input_width
        self.label_width = label_width
        self.shift = shift
        
        self.total_window_size = input_width + shift
        
        self.input_slice = slice(0, input_width)
        self.input_indices = np.arange(self.total_window_size)[self.input_slice]
        
        self.label_start = self.total_window_size - self.label_width
        self.labels_slice = slice(self.label_start, None)
        self.label_indices = np.arange(self.total_window_size)[self.labels_slice]
    
    def split_to_inputs_labels(self, features):
        inputs = features[:, self.input_slice, :]
        labels = features[:, self.labels_slice, :]
        if self.label_columns is not None:
            labels = tf.stack(
                [labels[:,:,self.column_indices[name]] for name in self.label_columns],
                axis=-1
            )
        inputs.set_shape([None, self.input_width, None])
        labels.set_shape([None, self.label_width, None])
        
        return inputs, labels
    
    def plot(self, model=None, plot_col='NO2', max_subplots=3):
        inputs, labels = self.sample_batch
        
        plt.figure(figsize=(12, 8))
        plot_col_index = self.column_indices[plot_col]
        max_n = min(max_subplots, len(inputs))
        
        for n in range(max_n):
            plt.subplot(3, 1, n+1)
            plt.ylabel(f'{plot_col} [scaled]')
            plt.plot(self.input_indices, inputs[n, :, plot_col_index],
                     label='Inputs', marker='.', zorder=-10)

            if self.label_columns:
              label_col_index = self.label_columns_indices.get(plot_col, None)
            else:
              label_col_index = plot_col_index

            if label_col_index is None:
              continue

            plt.scatter(self.label_indices, labels[n, :, label_col_index],
                        edgecolors='k', marker='s', label='Labels', c='green', s=64)
            if model is not None:
              predictions = model(inputs)
              plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                          marker='X', edgecolors='k', label='Predictions',
                          c='red', s=64)

            if n == 0:
              plt.legend()

        plt.xlabel('Time (h)')
        
    def make_dataset(self, data):
        data = np.array(data, dtype=np.float32)
        ds = tf.keras.preprocessing.timeseries_dataset_from_array(
            data=data,
            targets=None,
            sequence_length=self.total_window_size,
            sequence_stride=1,
            shuffle=True,
            batch_size=32
        )
        
        ds = ds.map(self.split_to_inputs_labels)
        return ds
    
    @property
    def train(self):
        return self.make_dataset(self.train_df)
    
    @property
    def val(self):
        return self.make_dataset(self.val_df)
    
    @property
    def test(self):
        return self.make_dataset(self.test_df)
    
    @property
    def sample_batch(self):
        result = getattr(self, '_sample_batch', None)
        if result is None:
            result = next(iter(self.train))
            self._sample_batch = result
        return result

# %%
def compile_and_fit(model, window, patience=3, max_epochs=50):
    early_stopping = EarlyStopping(monitor='val_loss',
                                   patience=patience,
                                   mode='min')
    
    model.compile(loss=MeanSquaredError(),
                  optimizer=Adam(),
                  metrics=[MeanAbsoluteError()])
    
    history = model.fit(window.train,
                       epochs=max_epochs,
                       validation_data=window.val,
                       callbacks=[early_stopping])
    
    return history

# %%
column_indices = {name: i for i, name in enumerate(train_df.columns)}

# %% [markdown]
# ## Single-step model

# %% [markdown]
# #### Build an LSTM model

# %%
single_step_window = DataWindow(input_width=1, label_width=1, shift=1, label_columns=['NO2']) 
wide_window = DataWindow(input_width=24, label_width=24, shift=1, label_columns=['NO2'])

# %%
lstm_model = Sequential([
    LSTM(32, return_sequences=True),
    Dense(units=1)
])

history = compile_and_fit(lstm_model, wide_window)

val_performance = {}
performance = {}

val_performance['LSTM'] = lstm_model.evaluate(wide_window.val)
performance['LSTM'] = lstm_model.evaluate(wide_window.test, verbose=0)
# Out:
# Epoch 1/50
# 413/413 [==============================] - 6s 11ms/step - loss: 0.0079 - mean_absolute_error: 0.0590 - val_loss: 0.0025 - val_mean_absolute_error: 0.0347
# Epoch 2/50
# 413/413 [==============================] - 5s 13ms/step - loss: 0.0021 - mean_absolute_error: 0.0319 - val_loss: 0.0019 - val_mean_absolute_error: 0.0295
# Epoch 3/50
# 413/413 [==============================] - 6s 14ms/step - loss: 0.0017 - mean_absolute_error: 0.0276 - val_loss: 0.0018 - val_mean_absolute_error: 0.0275
# Epoch 4/50
# 413/413 [==============================] - 6s 14ms/step - loss: 0.0015 - mean_absolute_error: 0.0259 - val_loss: 0.0018 - val_mean_absolute_error: 0.0269
# Epoch 5/50
# 413/413 [==============================] - 6s 15ms/step - loss: 0.0015 - mean_absolute_error: 0.0252 - val_loss: 0.0018 - val_mean_absolute_error: 0.0266
# Epoch 6/50
# 413/413 [==============================] - 6s 15ms/step - loss: 0.0015 - mean_absolute_error: 0.0249 - val_loss: 0.0018 - val_mean_absolute_error: 0.0268
# Epoch 7/50
# 413/413 [==============================] - 5s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0247 - val_loss: 0.0019 - val_mean_absolute_error: 0.0271
# 118/118 [==============================] - 1s 5ms/step - loss: 0.0019 - mean_absolute_error: 0.0271

# %%
# Values obtained from chapter 14

mae_val = [0.029, 0.028, 0.029]
mae_test = [0.033, 0.032, 0.034]

# %% [markdown]
# #### Plot its predictions

# %%
wide_window.plot(lstm_model)

# %% [markdown]
# #### Evaluate it using the MAE and store the MAE

# %%
mae_val.append(val_performance['LSTM'][1])
mae_test.append(performance['LSTM'][1])

x = np.arange(4)

labels = ['Baseline - Last', 'Linear', 'Dense', 'LSTM']

fig, ax = plt.subplots()
ax.bar(x - 0.15, mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(mae_val):
    plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
plt.ylim(0, 0.05)
plt.xticks(ticks=x, labels=labels)
plt.legend(loc='best')
plt.tight_layout()

# %% [markdown]
# #### Is it the most performant model?

# %% [markdown]
#     LSTM

# %% [markdown]
# ## Multi-step model

# %% [markdown]
# #### Build an LSTM model

# %%
multi_window = DataWindow(input_width=24, label_width=24, shift=24, label_columns=['NO2'])

# %%
ms_lstm_model = Sequential([
    LSTM(32, return_sequences=True),
    Dense(1, kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(ms_lstm_model, multi_window)

ms_val_performance = {}
ms_performance = {}

ms_val_performance['LSTM'] = ms_lstm_model.evaluate(multi_window.val)
ms_performance['LSTM'] = ms_lstm_model.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/50
# 413/413 [==============================] - 12s 16ms/step - loss: 0.0140 - mean_absolute_error: 0.0898 - val_loss: 0.0088 - val_mean_absolute_error: 0.0707
# Epoch 2/50
# 413/413 [==============================] - 6s 14ms/step - loss: 0.0116 - mean_absolute_error: 0.0819 - val_loss: 0.0086 - val_mean_absolute_error: 0.0695
# Epoch 3/50
# 413/413 [==============================] - 5s 13ms/step - loss: 0.0111 - mean_absolute_error: 0.0802 - val_loss: 0.0087 - val_mean_absolute_error: 0.0697
# Epoch 4/50
# 413/413 [==============================] - 6s 14ms/step - loss: 0.0108 - mean_absolute_error: 0.0789 - val_loss: 0.0086 - val_mean_absolute_error: 0.0699
# Epoch 5/50
# 413/413 [==============================] - 6s 14ms/step - loss: 0.0107 - mean_absolute_error: 0.0784 - val_loss: 0.0088 - val_mean_absolute_error: 0.0697
# Epoch 6/50
# 413/413 [==============================] - 6s 14ms/step - loss: 0.0105 - mean_absolute_error: 0.0775 - val_loss: 0.0086 - val_mean_absolute_error: 0.0690
# Epoch 7/50
# 413/413 [==============================] - 5s 13ms/step - loss: 0.0104 - mean_absolute_error: 0.0774 - val_loss: 0.0091 - val_mean_absolute_error: 0.0706
# 117/117 [==============================] - 1s 6ms/step - loss: 0.0091 - mean_absolute_error: 0.0706

# %% [markdown]
# #### Plot its predictions

# %%
wide_window.plot(ms_lstm_model)

# %% [markdown]
# #### Evaluate it using the MAE and store the MAE

# %%
# Values obtained from chapter 14

ms_mae_val = [0.282, 0.282, 0.070, 0.071]
ms_mae_test = [0.243, 0.244, 0.115, 0.114]

# %%
ms_mae_val.append(ms_val_performance['LSTM'][1])
ms_mae_test.append(ms_performance['LSTM'][1])

x = np.arange(5)

labels = ['Baseline - Last', 'Baseline - Repeat', 'Linear', 'Dense', 'LSTM']

fig, ax = plt.subplots()
ax.bar(x - 0.15, ms_mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, ms_mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(ms_mae_val):
    plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(ms_mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

plt.ylim(0, 0.4)
plt.xticks(ticks=x, labels=labels)
plt.legend(loc='best')
plt.tight_layout()

# %% [markdown]
# #### Is it the most performant model?

# %% [markdown]
#     LSTM

# %% [markdown]
# ## Multi-output model

# %% [markdown]
# #### Build an LSTM model

# %%
mo_single_step_window = DataWindow(input_width=1, label_width=1, shift=1, label_columns=['NO2','TEMP']) 
mo_wide_window = DataWindow(input_width=24, label_width=24, shift=1, label_columns=['NO2','TEMP'])

# %%
print(column_indices['NO2'])
print(column_indices['TEMP'])
# Out:
# 3
# 6

# %%
mo_lstm_model = Sequential([
    LSTM(32, return_sequences=True),
    Dense(units = 2)
])

history = compile_and_fit(mo_lstm_model, mo_wide_window)

mo_val_performance = {}
mo_performance = {}

mo_val_performance['LSTM'] = mo_lstm_model.evaluate(mo_wide_window.val)
mo_performance['LSTM'] = mo_lstm_model.evaluate(mo_wide_window.test, verbose=0)
# Out:
# Epoch 1/50
# 413/413 [==============================] - 10s 14ms/step - loss: 0.0106 - mean_absolute_error: 0.0655 - val_loss: 0.0031 - val_mean_absolute_error: 0.0370
# Epoch 2/50
# 413/413 [==============================] - 5s 12ms/step - loss: 0.0022 - mean_absolute_error: 0.0324 - val_loss: 0.0016 - val_mean_absolute_error: 0.0273
# Epoch 3/50
# 413/413 [==============================] - 6s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0259 - val_loss: 0.0013 - val_mean_absolute_error: 0.0238
# Epoch 4/50
# 413/413 [==============================] - 6s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0230 - val_loss: 0.0012 - val_mean_absolute_error: 0.0218
# Epoch 5/50
# 413/413 [==============================] - 5s 13ms/step - loss: 0.0010 - mean_absolute_error: 0.0212 - val_loss: 0.0011 - val_mean_absolute_error: 0.0208
# Epoch 6/50
# 413/413 [==============================] - 5s 13ms/step - loss: 9.7679e-04 - mean_absolute_error: 0.0202 - val_loss: 0.0011 - val_mean_absolute_error: 0.0204
# Epoch 7/50
# 413/413 [==============================] - 5s 13ms/step - loss: 9.3956e-04 - mean_absolute_error: 0.0194 - val_loss: 0.0011 - val_mean_absolute_error: 0.0196
# Epoch 8/50
# 413/413 [==============================] - 5s 13ms/step - loss: 9.1562e-04 - mean_absolute_error: 0.0190 - val_loss: 0.0011 - val_mean_absolute_error: 0.0191
# Epoch 9/50
# 413/413 [==============================] - 5s 13ms/step - loss: 8.9915e-04 - mean_absolute_error: 0.0186 - val_loss: 0.0011 - val_mean_absolute_error: 0.0194
# Epoch 10/50
# 413/413 [==============================] - 5s 13ms/step - loss: 8.8785e-04 - mean_absolute_error: 0.0184 - val_loss: 0.0011 - val_mean_absolute_error: 0.0193
# Epoch 11/50
# 413/413 [==============================] - 6s 13ms/step - loss: 8.7817e-04 - mean_absolute_error: 0.0183 - val_loss: 0.0011 - val_mean_absolute_error: 0.0187
# Epoch 12/50
# 413/413 [==============================] - 5s 13ms/step - loss: 8.6920e-04 - mean_absolute_error: 0.0181 - val_loss: 0.0010 - val_mean_absolute_error: 0.0184
# Epoch 13/50
# 413/413 [==============================] - 6s 13ms/step - loss: 8.6113e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0010 - val_mean_absolute_error: 0.0185
# Epoch 14/50
# 413/413 [==============================] - 5s 12ms/step - loss: 8.5483e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0011 - val_mean_absolute_error: 0.0185
# Epoch 15/50
# 413/413 [==============================] - 5s 12ms/step - loss: 8.4798e-04 - mean_absolute_error: 0.0179 - val_loss: 0.0011 - val_mean_absolute_error: 0.0188
# Epoch 16/50
# 413/413 [==============================] - 6s 13ms/step - loss: 8.4326e-04 - mean_absolute_error: 0.0179 - val_loss: 0.0010 - val_mean_absolute_error: 0.0185
# Epoch 17/50
# 413/413 [==============================] - 5s 13ms/step - loss: 8.3676e-04 - mean_absolute_error: 0.0178 - val_loss: 0.0010 - val_mean_absolute_error: 0.0183
# Epoch 18/50
# 413/413 [==============================] - 6s 14ms/step - loss: 8.3421e-04 - mean_absolute_error: 0.0178 - val_loss: 0.0010 - val_mean_absolute_error: 0.0183
# Epoch 19/50
# 413/413 [==============================] - 5s 13ms/step - loss: 8.3043e-04 - mean_absolute_error: 0.0177 - val_loss: 0.0010 - val_mean_absolute_error: 0.0183
# Epoch 20/50
# 413/413 [==============================] - 5s 13ms/step - loss: 8.2792e-04 - mean_absolute_error: 0.0177 - val_loss: 0.0010 - val_mean_absolute_error: 0.0185
# Epoch 21/50
# 413/413 [==============================] - 5s 13ms/step - loss: 8.2246e-04 - mean_absolute_error: 0.0177 - val_loss: 0.0010 - val_mean_absolute_error: 0.0186
# 118/118 [==============================] - 1s 5ms/step - loss: 0.0010 - mean_absolute_error: 0.0186

# %% [markdown]
# #### Plot its predictions

# %%
mo_wide_window.plot(mo_lstm_model)

# %% [markdown]
# #### Evaluate it using the MAE and store the MAE

# %%
# Values from chapter 14

mo_mae_val = [0.021, 0.020, 0.020]
mo_mae_test = [0.025, 0.023, 0.025]

# %%
mo_mae_val.append(mo_val_performance['LSTM'][1])
mo_mae_test.append(mo_performance['LSTM'][1])

x = np.arange(4)

labels = ['Baseline - Last', 'Linear', 'Dense', 'LSTM']

fig, ax = plt.subplots()
ax.bar(x - 0.15, mo_mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, mo_mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(mo_mae_val):
    plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(mo_mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

plt.ylim(0, 0.06)
plt.xticks(ticks=x, labels=labels)
plt.legend(loc='best')
plt.tight_layout()

# %% [markdown]
# #### Is it the most performant model?

# %% [markdown]
#     LSTM

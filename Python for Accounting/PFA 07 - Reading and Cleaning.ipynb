# %% [markdown]
# # Chapter 20 - Project: Reading and cleaning a QuickBooks general ledger

# %%
import pandas as pd

# %%
ledger_df = pd.read_excel('data/QuickBooks GL.xlsx')
ledger_df
# Out:
#     Carl's Design and Landscaping Services Unnamed: 1  Unnamed: 2  \
# 0                           General Ledger        NaN         NaN
# 1                                All Dates        NaN         NaN
# 2                                      NaN        NaN         NaN
# 3                                     Acct    SubAcct        Date
# 4                                 Checking        NaN         NaN
# ..                                     ...        ...         ...
# 443                                    NaN        NaN  12/28/2020
# 444                Total for Miscellaneous        NaN         NaN
# 445                          Not Specified        NaN         NaN
# 446                                    NaN        NaN  12/18/2020
# 447                Total for Not Specified        NaN         NaN
#
#            Unnamed: 3 Unnamed: 4                  Unnamed: 5  \
# 0                 NaN        NaN                         NaN
# 1                 NaN        NaN                         NaN
# 2                 NaN        NaN                         NaN
# 3    Transaction Type        Num                        Name
# 4                 NaN        NaN                         NaN
# ..                ...        ...                         ...
# 443              Bill        NaN  Brosnahan Insurance Agency
# 444               NaN        NaN                         NaN
# 445               NaN        NaN                         NaN
# 446           Payment        NaN        Amy's Bird Sanctuary
# 447               NaN        NaN                         NaN
#
#                                            Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0                                                 NaN        NaN        NaN
# 1                                                 NaN        NaN        NaN
# 2                                                 NaN        NaN        NaN
# 3                                    Memo/Description      Debit     Credit
# 4                                                 NaN        NaN        NaN
# ..                                                ...        ...        ...
# 443                                               NaN       2000        NaN
# 444                                               NaN       2916        NaN
# 445                                               NaN        NaN        NaN
# 446  Created by QB Online to link credits to charges.          0        NaN
# 447                                               NaN          0        NaN
#
#     Unnamed: 9
# 0          NaN
# 1          NaN
# 2          NaN
# 3      Balance
# 4          NaN
# ..         ...
# 443       2916
# 444        NaN
# 445        NaN
# 446          0
# 447        NaN
#
# [448 rows x 10 columns]

# %%
# Skip the first four rows when reading
ledger_df = pd.read_excel('data/QuickBooks GL.xlsx', skiprows=4)
ledger_df
# Out:
#                         Acct SubAcct        Date      Transaction Type   Num  \
# 0                   Checking     NaN         NaN                   NaN   NaN
# 1                        NaN     NaN  08/21/2020               Deposit   NaN
# 2                        NaN     NaN  10/02/2020  Bill Payment (Check)    10
# 3                        NaN     NaN  10/10/2020               Payment  1053
# 4                        NaN     NaN  10/24/2020               Expense    12
# ..                       ...     ...         ...                   ...   ...
# 439                      NaN     NaN  12/28/2020                  Bill   NaN
# 440  Total for Miscellaneous     NaN         NaN                   NaN   NaN
# 441            Not Specified     NaN         NaN                   NaN   NaN
# 442                      NaN     NaN  12/18/2020               Payment   NaN
# 443  Total for Not Specified     NaN         NaN                   NaN   NaN
#
#                            Name  \
# 0                           NaN
# 1                           NaN
# 2        Robertson & Associates
# 3          Bill's Windsurf Shop
# 4        Robertson & Associates
# ..                          ...
# 439  Brosnahan Insurance Agency
# 440                         NaN
# 441                         NaN
# 442        Amy's Bird Sanctuary
# 443                         NaN
#
#                                      Memo/Description Debit Credit  Balance
# 0                                                 NaN   NaN    NaN      NaN
# 1                                     Opening Balance  5000    NaN   5000.0
# 2                                                 NaN   NaN    300   4700.0
# 3                                                 NaN   175    NaN   4875.0
# 4                                                 NaN   NaN    250   4625.0
# ..                                                ...   ...    ...      ...
# 439                                               NaN  2000    NaN   2916.0
# 440                                               NaN  2916    NaN      NaN
# 441                                               NaN   NaN    NaN      NaN
# 442  Created by QB Online to link credits to charges.     0    NaN      0.0
# 443                                               NaN     0    NaN      NaN
#
# [444 rows x 10 columns]

# %%
# Drop columns where all values are NaN (empty), keeping only columns with at least one non-NaN value
ledger_df = ledger_df.dropna(how='all', axis='columns')  

# Drop rows where all values are NaN (empty), keeping only rows with at least one non-NaN value
ledger_df = ledger_df.dropna(how='all', axis='rows')  

# Rename columns: 'Acct' to 'Account' and 'SubAcct' to 'SubAccount'
ledger_df = ledger_df.rename(columns={'Acct': 'Account', 'SubAcct': 'SubAccount'})  

ledger_df
# Out:
#                      Account SubAccount        Date      Transaction Type  \
# 0                   Checking        NaN         NaN                   NaN
# 1                        NaN        NaN  08/21/2020               Deposit
# 2                        NaN        NaN  10/02/2020  Bill Payment (Check)
# 3                        NaN        NaN  10/10/2020               Payment
# 4                        NaN        NaN  10/24/2020               Expense
# ..                       ...        ...         ...                   ...
# 439                      NaN        NaN  12/28/2020                  Bill
# 440  Total for Miscellaneous        NaN         NaN                   NaN
# 441            Not Specified        NaN         NaN                   NaN
# 442                      NaN        NaN  12/18/2020               Payment
# 443  Total for Not Specified        NaN         NaN                   NaN
#
#       Num                        Name  \
# 0     NaN                         NaN
# 1     NaN                         NaN
# 2      10      Robertson & Associates
# 3    1053        Bill's Windsurf Shop
# 4      12      Robertson & Associates
# ..    ...                         ...
# 439   NaN  Brosnahan Insurance Agency
# 440   NaN                         NaN
# 441   NaN                         NaN
# 442   NaN        Amy's Bird Sanctuary
# 443   NaN                         NaN
#
#                                      Memo/Description Debit Credit  Balance
# 0                                                 NaN   NaN    NaN      NaN
# 1                                     Opening Balance  5000    NaN   5000.0
# 2                                                 NaN   NaN    300   4700.0
# 3                                                 NaN   175    NaN   4875.0
# 4                                                 NaN   NaN    250   4625.0
# ..                                                ...   ...    ...      ...
# 439                                               NaN  2000    NaN   2916.0
# 440                                               NaN  2916    NaN      NaN
# 441                                               NaN   NaN    NaN      NaN
# 442  Created by QB Online to link credits to charges.     0    NaN      0.0
# 443                                               NaN     0    NaN      NaN
#
# [444 rows x 10 columns]

# %%
# Forward fill missing (NaN) values in the 'Account' column with the previous non-null value
ledger_df['Account'] = ledger_df['Account'].ffill()  
ledger_df
# Out:
#                      Account SubAccount        Date      Transaction Type  \
# 0                   Checking        NaN         NaN                   NaN
# 1                   Checking        NaN  08/21/2020               Deposit
# 2                   Checking        NaN  10/02/2020  Bill Payment (Check)
# 3                   Checking        NaN  10/10/2020               Payment
# 4                   Checking        NaN  10/24/2020               Expense
# ..                       ...        ...         ...                   ...
# 439            Miscellaneous        NaN  12/28/2020                  Bill
# 440  Total for Miscellaneous        NaN         NaN                   NaN
# 441            Not Specified        NaN         NaN                   NaN
# 442            Not Specified        NaN  12/18/2020               Payment
# 443  Total for Not Specified        NaN         NaN                   NaN
#
#       Num                        Name  \
# 0     NaN                         NaN
# 1     NaN                         NaN
# 2      10      Robertson & Associates
# 3    1053        Bill's Windsurf Shop
# 4      12      Robertson & Associates
# ..    ...                         ...
# 439   NaN  Brosnahan Insurance Agency
# 440   NaN                         NaN
# 441   NaN                         NaN
# 442   NaN        Amy's Bird Sanctuary
# 443   NaN                         NaN
#
#                                      Memo/Description Debit Credit  Balance
# 0                                                 NaN   NaN    NaN      NaN
# 1                                     Opening Balance  5000    NaN   5000.0
# 2                                                 NaN   NaN    300   4700.0
# 3                                                 NaN   175    NaN   4875.0
# 4                                                 NaN   NaN    250   4625.0
# ..                                                ...   ...    ...      ...
# 439                                               NaN  2000    NaN   2916.0
# 440                                               NaN  2916    NaN      NaN
# 441                                               NaN   NaN    NaN      NaN
# 442  Created by QB Online to link credits to charges.     0    NaN      0.0
# 443                                               NaN     0    NaN      NaN
#
# [444 rows x 10 columns]

# %%
ledger_df['Account'].value_counts()
# Out:
# Account
# Landscaping Services                 61
# Accounts Receivable (A/R)            49
# Checking                             45
# Accounts Payable (A/P)               26
# Inventory Asset                      21
#                                      ..
# Total for Checking                    1
# Total for Sales of Product Income     1
# Total for Services                    1
# Total for Cost of Goods Sold          1
# Total for Not Specified               1
# Name: count, Length: 66, dtype: int64

# %%
ledger_df['SubAccount'].value_counts()
# Out:
# SubAccount
# Total for Job Materials                    2
# Job Materials                              2
# Plants and Soil                            2
# Total for Plants and Soil                  2
# Sprinklers and Drip Systems                2
# Total for Sprinklers and Drip Systems      2
# Total for Maintenance and Repair           2
# Total for Lawyer                           1
# Accounting                                 1
# Total for Accounting                       1
# Bookkeeper                                 1
# Total for Bookkeeper                       1
# Lawyer                                     1
# Original Cost                              1
# Equipment Repairs                          1
# Total for Equipment Repairs                1
# Total for Decks and Patios                 1
# Gas and Electric                           1
# Total for Gas and Electric                 1
# Telephone                                  1
# Total for Legal & Professional Fees        1
# Fuel                                       1
# Decks and Patios                           1
# Total for Job Expenses                     1
# Total for Fuel                             1
# Total for Original Cost                    1
# Total for Automobile                       1
# Total for Labor                            1
# Maintenance and Repair                     1
# Total for Installation                     1
# Installation                               1
# Labor                                      1
# Total for Fountains and Garden Lighting    1
# Fountains and Garden Lighting              1
# Total for Landscaping Services             1
# Total for Telephone                        1
# Name: count, dtype: int64

# %% [markdown]
# The function bellow first checks if name is not NaN (using pandas’s
# notna helper function), then checks if name contains the word
# 'Total'. It returns the combined value of these checks as a boolean
# (i.e., either True if both checks are True , or False if either of them
# is False ). The first check isn’t strictly necessary, but it prevents
# the function from triggering an error if it gets a NaN value as its
# input.

# %%
# Define a function named 'is_subtotal' that checks if a string contains 'Total' and is not NaN
def is_subtotal(name):  
    return pd.notna(name) and 'Total' in name  # Check if 'name' is not NaN and if it contains the substring 'Total'

# %%
# Test 1
is_subtotal('Accounts Receivable (A/R)')
# Out:
# False

# %%
# Test 2
is_subtotal('Total for Notes Payable')
# Out:
# True

# %%
valid_accounts = [name for name in ledger_df['Account'].unique() if not is_subtotal(name)]
valid_accounts
# Out:
# ['Checking',
#  'Savings',
#  'Accounts Receivable (A/R)',
#  'Inventory Asset',
#  'Undeposited Funds',
#  'Truck',
#  'Accounts Payable (A/P)',
#  'Mastercard',
#  'Arizona Dept. of Revenue Payable',
#  'Board of Equalization Payable',
#  'Loan Payable',
#  'Notes Payable',
#  'Opening Balance Equity',
#  'Design income',
#  'Discounts given',
#  'Landscaping Services',
#  'Pest Control Services',
#  'Sales of Product Income',
#  'Services',
#  'Cost of Goods Sold',
#  'Advertising',
#  'Automobile',
#  'Equipment Rental',
#  'Insurance',
#  'Job Expenses',
#  'Legal & Professional Fees',
#  'Maintenance and Repair',
#  'Meals and Entertainment',
#  'Office Expenses',
#  'Rent or Lease',
#  'Utilities',
#  'Miscellaneous',
#  'Not Specified']

# %%
# Another way:

valid_accounts = []

for name in ledger_df['Account'].unique():
    if not is_subtotal(name):
        valid_accounts.append(name)

valid_accounts
# Out:
# ['Checking',
#  'Savings',
#  'Accounts Receivable (A/R)',
#  'Inventory Asset',
#  'Undeposited Funds',
#  'Truck',
#  'Accounts Payable (A/P)',
#  'Mastercard',
#  'Arizona Dept. of Revenue Payable',
#  'Board of Equalization Payable',
#  'Loan Payable',
#  'Notes Payable',
#  'Opening Balance Equity',
#  'Design income',
#  'Discounts given',
#  'Landscaping Services',
#  'Pest Control Services',
#  'Sales of Product Income',
#  'Services',
#  'Cost of Goods Sold',
#  'Advertising',
#  'Automobile',
#  'Equipment Rental',
#  'Insurance',
#  'Job Expenses',
#  'Legal & Professional Fees',
#  'Maintenance and Repair',
#  'Meals and Entertainment',
#  'Office Expenses',
#  'Rent or Lease',
#  'Utilities',
#  'Miscellaneous',
#  'Not Specified']

# %%
# Filter the 'ledger_df' DataFrame to keep only rows where 'Account' is in the 'valid_accounts' list
ledger_df = ledger_df[ledger_df['Account'].isin(valid_accounts)]  
ledger_df
# Out:
#            Account SubAccount        Date      Transaction Type   Num  \
# 0         Checking        NaN         NaN                   NaN   NaN
# 1         Checking        NaN  08/21/2020               Deposit   NaN
# 2         Checking        NaN  10/02/2020  Bill Payment (Check)    10
# 3         Checking        NaN  10/10/2020               Payment  1053
# 4         Checking        NaN  10/24/2020               Expense    12
# ..             ...        ...         ...                   ...   ...
# 437  Miscellaneous        NaN  11/28/2020                  Bill   NaN
# 438  Miscellaneous        NaN  12/20/2020                  Bill   NaN
# 439  Miscellaneous        NaN  12/28/2020                  Bill   NaN
# 441  Not Specified        NaN         NaN                   NaN   NaN
# 442  Not Specified        NaN  12/18/2020               Payment   NaN
#
#                            Name  \
# 0                           NaN
# 1                           NaN
# 2        Robertson & Associates
# 3          Bill's Windsurf Shop
# 4        Robertson & Associates
# ..                          ...
# 437              Hicks Hardware
# 438          Tim Philip Masonry
# 439  Brosnahan Insurance Agency
# 441                         NaN
# 442        Amy's Bird Sanctuary
#
#                                      Memo/Description Debit Credit  Balance
# 0                                                 NaN   NaN    NaN      NaN
# 1                                     Opening Balance  5000    NaN   5000.0
# 2                                                 NaN   NaN    300   4700.0
# 3                                                 NaN   175    NaN   4875.0
# 4                                                 NaN   NaN    250   4625.0
# ..                                                ...   ...    ...      ...
# 437                                               NaN   250    NaN    250.0
# 438                                               NaN   666    NaN    916.0
# 439                                               NaN  2000    NaN   2916.0
# 441                                               NaN   NaN    NaN      NaN
# 442  Created by QB Online to link credits to charges.     0    NaN      0.0
#
# [411 rows x 10 columns]

# %%
def is_subtotal(name):                         # Define a function that checks if a name is not NaN and contains the word 'Total'
    return pd.notna(name) and 'Total' in name  # Returns True if 'name' is not NaN and contains 'Total'

valid_accounts = [name for name in ledger_df['Account'].unique()  # Create a list of unique 'Account' values from 'ledger_df'
    if not is_subtotal(name)]                                     # Include only accounts that do not contain 'Total'

valid_subaccounts = [name for name in ledger_df['SubAccount'].unique()  # Create a list of unique 'SubAccount' values from 'ledger_df'
    if not is_subtotal(name)]                                           # Include only subaccounts that do not contain 'Total'

ledger_df = ledger_df[ledger_df['Account'].isin(valid_accounts)]        # Filter the DataFrame to keep rows where 'Account' is in valid_accounts
ledger_df = ledger_df[ledger_df['SubAccount'].isin(valid_subaccounts)]  # Filter the DataFrame to keep rows where 'SubAccount' is in valid_subaccounts

ledger_df
# Out:
#            Account SubAccount        Date      Transaction Type   Num  \
# 0         Checking        NaN         NaN                   NaN   NaN
# 1         Checking        NaN  08/21/2020               Deposit   NaN
# 2         Checking        NaN  10/02/2020  Bill Payment (Check)    10
# 3         Checking        NaN  10/10/2020               Payment  1053
# 4         Checking        NaN  10/24/2020               Expense    12
# ..             ...        ...         ...                   ...   ...
# 437  Miscellaneous        NaN  11/28/2020                  Bill   NaN
# 438  Miscellaneous        NaN  12/20/2020                  Bill   NaN
# 439  Miscellaneous        NaN  12/28/2020                  Bill   NaN
# 441  Not Specified        NaN         NaN                   NaN   NaN
# 442  Not Specified        NaN  12/18/2020               Payment   NaN
#
#                            Name  \
# 0                           NaN
# 1                           NaN
# 2        Robertson & Associates
# 3          Bill's Windsurf Shop
# 4        Robertson & Associates
# ..                          ...
# 437              Hicks Hardware
# 438          Tim Philip Masonry
# 439  Brosnahan Insurance Agency
# 441                         NaN
# 442        Amy's Bird Sanctuary
#
#                                      Memo/Description Debit Credit  Balance
# 0                                                 NaN   NaN    NaN      NaN
# 1                                     Opening Balance  5000    NaN   5000.0
# 2                                                 NaN   NaN    300   4700.0
# 3                                                 NaN   175    NaN   4875.0
# 4                                                 NaN   NaN    250   4625.0
# ..                                                ...   ...    ...      ...
# 437                                               NaN   250    NaN    250.0
# 438                                               NaN   666    NaN    916.0
# 439                                               NaN  2000    NaN   2916.0
# 441                                               NaN   NaN    NaN      NaN
# 442  Created by QB Online to link credits to charges.     0    NaN      0.0
#
# [387 rows x 10 columns]

# %%
ledger_df['Account'].value_counts()
# Out:
# Account
# Landscaping Services                53
# Accounts Receivable (A/R)           49
# Checking                            45
# Accounts Payable (A/P)              26
# Inventory Asset                     21
# Undeposited Funds                   21
# Mastercard                          18
# Board of Equalization Payable       17
# Job Expenses                        15
# Opening Balance Equity              14
# Automobile                          13
# Legal & Professional Fees           11
# Sales of Product Income              9
# Pest Control Services                9
# Cost of Goods Sold                   7
# Utilities                            7
# Design income                        7
# Discounts given                      4
# Meals and Entertainment              4
# Miscellaneous                        4
# Arizona Dept. of Revenue Payable     4
# Maintenance and Repair               4
# Savings                              3
# Services                             3
# Truck                                3
# Rent or Lease                        2
# Office Expenses                      2
# Insurance                            2
# Equipment Rental                     2
# Loan Payable                         2
# Advertising                          2
# Notes Payable                        2
# Not Specified                        2
# Name: count, dtype: int64

# %%
ledger_df[ledger_df['Account'] == 'Utilities']
# Out:
#        Account        SubAccount        Date Transaction Type  Num  \
# 426  Utilities               NaN         NaN              NaN  NaN
# 427  Utilities  Gas and Electric         NaN              NaN  NaN
# 428  Utilities               NaN  11/20/2020             Bill  NaN
# 429  Utilities               NaN  12/19/2020             Bill  NaN
# 431  Utilities         Telephone         NaN              NaN  NaN
# 432  Utilities               NaN  11/19/2020             Bill  NaN
# 433  Utilities               NaN  12/19/2020             Bill  NaN
#
#               Name    Memo/Description   Debit Credit  Balance
# 426            NaN                 NaN     NaN    NaN      NaN
# 427            NaN                 NaN     NaN    NaN      NaN
# 428           PG&E                 NaN   86.44    NaN    86.44
# 429           PG&E                 NaN  114.09    NaN   200.53
# 431            NaN                 NaN     NaN    NaN      NaN
# 432  Cal Telephone                 NaN    56.5    NaN    56.50
# 433  Cal Telephone  Monthly Phone Bill   74.36    NaN   130.86

# %%
# Filter 'ledger_df' to include only rows where the 'Account' column contains 'Utilities' or 'Miscellaneous'
example_df = ledger_df[ledger_df['Account'].isin(['Utilities', 'Miscellaneous'])]
example_df
# Out:
#            Account        SubAccount        Date Transaction Type  Num  \
# 426      Utilities               NaN         NaN              NaN  NaN
# 427      Utilities  Gas and Electric         NaN              NaN  NaN
# 428      Utilities               NaN  11/20/2020             Bill  NaN
# 429      Utilities               NaN  12/19/2020             Bill  NaN
# 431      Utilities         Telephone         NaN              NaN  NaN
# 432      Utilities               NaN  11/19/2020             Bill  NaN
# 433      Utilities               NaN  12/19/2020             Bill  NaN
# 436  Miscellaneous               NaN         NaN              NaN  NaN
# 437  Miscellaneous               NaN  11/28/2020             Bill  NaN
# 438  Miscellaneous               NaN  12/20/2020             Bill  NaN
# 439  Miscellaneous               NaN  12/28/2020             Bill  NaN
#
#                            Name    Memo/Description   Debit Credit  Balance
# 426                         NaN                 NaN     NaN    NaN      NaN
# 427                         NaN                 NaN     NaN    NaN      NaN
# 428                        PG&E                 NaN   86.44    NaN    86.44
# 429                        PG&E                 NaN  114.09    NaN   200.53
# 431                         NaN                 NaN     NaN    NaN      NaN
# 432               Cal Telephone                 NaN    56.5    NaN    56.50
# 433               Cal Telephone  Monthly Phone Bill   74.36    NaN   130.86
# 436                         NaN                 NaN     NaN    NaN      NaN
# 437              Hicks Hardware                 NaN     250    NaN   250.00
# 438          Tim Philip Masonry                 NaN     666    NaN   916.00
# 439  Brosnahan Insurance Agency                 NaN    2000    NaN  2916.00

# %%
# Forward fill missing (NaN) values in the 'SubAccount' column with the previous non-null value
example_df.loc[:, 'SubAccount'] = example_df['SubAccount'].ffill()
example_df
# Out:
#            Account        SubAccount        Date Transaction Type  Num  \
# 426      Utilities               NaN         NaN              NaN  NaN
# 427      Utilities  Gas and Electric         NaN              NaN  NaN
# 428      Utilities  Gas and Electric  11/20/2020             Bill  NaN
# 429      Utilities  Gas and Electric  12/19/2020             Bill  NaN
# 431      Utilities         Telephone         NaN              NaN  NaN
# 432      Utilities         Telephone  11/19/2020             Bill  NaN
# 433      Utilities         Telephone  12/19/2020             Bill  NaN
# 436  Miscellaneous         Telephone         NaN              NaN  NaN
# 437  Miscellaneous         Telephone  11/28/2020             Bill  NaN
# 438  Miscellaneous         Telephone  12/20/2020             Bill  NaN
# 439  Miscellaneous         Telephone  12/28/2020             Bill  NaN
#
#                            Name    Memo/Description   Debit Credit  Balance
# 426                         NaN                 NaN     NaN    NaN      NaN
# 427                         NaN                 NaN     NaN    NaN      NaN
# 428                        PG&E                 NaN   86.44    NaN    86.44
# 429                        PG&E                 NaN  114.09    NaN   200.53
# 431                         NaN                 NaN     NaN    NaN      NaN
# 432               Cal Telephone                 NaN    56.5    NaN    56.50
# 433               Cal Telephone  Monthly Phone Bill   74.36    NaN   130.86
# 436                         NaN                 NaN     NaN    NaN      NaN
# 437              Hicks Hardware                 NaN     250    NaN   250.00
# 438          Tim Philip Masonry                 NaN     666    NaN   916.00
# 439  Brosnahan Insurance Agency                 NaN    2000    NaN  2916.00

# %%
# Forward fill missing (NaN) values in the 'SubAccount' column with the next non-null value
example_df.loc[:, 'SubAccount'] = example_df['SubAccount'].bfill()
example_df
# Out:
#            Account        SubAccount        Date Transaction Type  Num  \
# 426      Utilities  Gas and Electric         NaN              NaN  NaN
# 427      Utilities  Gas and Electric         NaN              NaN  NaN
# 428      Utilities  Gas and Electric  11/20/2020             Bill  NaN
# 429      Utilities  Gas and Electric  12/19/2020             Bill  NaN
# 431      Utilities         Telephone         NaN              NaN  NaN
# 432      Utilities         Telephone  11/19/2020             Bill  NaN
# 433      Utilities         Telephone  12/19/2020             Bill  NaN
# 436  Miscellaneous         Telephone         NaN              NaN  NaN
# 437  Miscellaneous         Telephone  11/28/2020             Bill  NaN
# 438  Miscellaneous         Telephone  12/20/2020             Bill  NaN
# 439  Miscellaneous         Telephone  12/28/2020             Bill  NaN
#
#                            Name    Memo/Description   Debit Credit  Balance
# 426                         NaN                 NaN     NaN    NaN      NaN
# 427                         NaN                 NaN     NaN    NaN      NaN
# 428                        PG&E                 NaN   86.44    NaN    86.44
# 429                        PG&E                 NaN  114.09    NaN   200.53
# 431                         NaN                 NaN     NaN    NaN      NaN
# 432               Cal Telephone                 NaN    56.5    NaN    56.50
# 433               Cal Telephone  Monthly Phone Bill   74.36    NaN   130.86
# 436                         NaN                 NaN     NaN    NaN      NaN
# 437              Hicks Hardware                 NaN     250    NaN   250.00
# 438          Tim Philip Masonry                 NaN     666    NaN   916.00
# 439  Brosnahan Insurance Agency                 NaN    2000    NaN  2916.00

# %% [markdown]
# Notice the 'SubAccount' value in the last four rows is 'Telephone',
# which isn’t a valid miscellaneous sub-account. To fill in missing
# values in the 'SubAccount' column, you need to call fillna on
# each account separately. We can do that with a for loop and the
# loc slicing operator:

# %%
import numpy as np

# Apply the condition to set 'SubAccount' to NaN where 'Account' == 'Miscellaneous' and 'SubAccount' == 'Telephone'
example_df.loc[(example_df['Account'] == 'Miscellaneous') & (example_df['SubAccount'] == 'Telephone'), 'SubAccount'] = np.nan

example_df
# Out:
#            Account        SubAccount        Date Transaction Type  Num  \
# 426      Utilities  Gas and Electric         NaN              NaN  NaN
# 427      Utilities  Gas and Electric         NaN              NaN  NaN
# 428      Utilities  Gas and Electric  11/20/2020             Bill  NaN
# 429      Utilities  Gas and Electric  12/19/2020             Bill  NaN
# 431      Utilities         Telephone         NaN              NaN  NaN
# 432      Utilities         Telephone  11/19/2020             Bill  NaN
# 433      Utilities         Telephone  12/19/2020             Bill  NaN
# 436  Miscellaneous               NaN         NaN              NaN  NaN
# 437  Miscellaneous               NaN  11/28/2020             Bill  NaN
# 438  Miscellaneous               NaN  12/20/2020             Bill  NaN
# 439  Miscellaneous               NaN  12/28/2020             Bill  NaN
#
#                            Name    Memo/Description   Debit Credit  Balance
# 426                         NaN                 NaN     NaN    NaN      NaN
# 427                         NaN                 NaN     NaN    NaN      NaN
# 428                        PG&E                 NaN   86.44    NaN    86.44
# 429                        PG&E                 NaN  114.09    NaN   200.53
# 431                         NaN                 NaN     NaN    NaN      NaN
# 432               Cal Telephone                 NaN    56.5    NaN    56.50
# 433               Cal Telephone  Monthly Phone Bill   74.36    NaN   130.86
# 436                         NaN                 NaN     NaN    NaN      NaN
# 437              Hicks Hardware                 NaN     250    NaN   250.00
# 438          Tim Philip Masonry                 NaN     666    NaN   916.00
# 439  Brosnahan Insurance Agency                 NaN    2000    NaN  2916.00

# %%
# Drop rows where all values in columns starting from the 3rd column (index 2) are NaN
example_df = example_df.dropna(subset=example_df.columns[2:], how='all')  

example_df
# Out:
#            Account        SubAccount        Date Transaction Type  Num  \
# 428      Utilities  Gas and Electric  11/20/2020             Bill  NaN
# 429      Utilities  Gas and Electric  12/19/2020             Bill  NaN
# 432      Utilities         Telephone  11/19/2020             Bill  NaN
# 433      Utilities         Telephone  12/19/2020             Bill  NaN
# 437  Miscellaneous               NaN  11/28/2020             Bill  NaN
# 438  Miscellaneous               NaN  12/20/2020             Bill  NaN
# 439  Miscellaneous               NaN  12/28/2020             Bill  NaN
#
#                            Name    Memo/Description   Debit Credit  Balance
# 428                        PG&E                 NaN   86.44    NaN    86.44
# 429                        PG&E                 NaN  114.09    NaN   200.53
# 432               Cal Telephone                 NaN    56.5    NaN    56.50
# 433               Cal Telephone  Monthly Phone Bill   74.36    NaN   130.86
# 437              Hicks Hardware                 NaN     250    NaN   250.00
# 438          Tim Philip Masonry                 NaN     666    NaN   916.00
# 439  Brosnahan Insurance Agency                 NaN    2000    NaN  2916.00

# %% [markdown]
# After all this scrubbing, what can you do with `ledger_df`? For
# instance, you can easily slice it to get postings in various accounts
# or sub-accounts:

# %%
ledger_df
# Out:
#            Account SubAccount        Date      Transaction Type   Num  \
# 0         Checking        NaN         NaN                   NaN   NaN
# 1         Checking        NaN  08/21/2020               Deposit   NaN
# 2         Checking        NaN  10/02/2020  Bill Payment (Check)    10
# 3         Checking        NaN  10/10/2020               Payment  1053
# 4         Checking        NaN  10/24/2020               Expense    12
# ..             ...        ...         ...                   ...   ...
# 437  Miscellaneous        NaN  11/28/2020                  Bill   NaN
# 438  Miscellaneous        NaN  12/20/2020                  Bill   NaN
# 439  Miscellaneous        NaN  12/28/2020                  Bill   NaN
# 441  Not Specified        NaN         NaN                   NaN   NaN
# 442  Not Specified        NaN  12/18/2020               Payment   NaN
#
#                            Name  \
# 0                           NaN
# 1                           NaN
# 2        Robertson & Associates
# 3          Bill's Windsurf Shop
# 4        Robertson & Associates
# ..                          ...
# 437              Hicks Hardware
# 438          Tim Philip Masonry
# 439  Brosnahan Insurance Agency
# 441                         NaN
# 442        Amy's Bird Sanctuary
#
#                                      Memo/Description Debit Credit  Balance
# 0                                                 NaN   NaN    NaN      NaN
# 1                                     Opening Balance  5000    NaN   5000.0
# 2                                                 NaN   NaN    300   4700.0
# 3                                                 NaN   175    NaN   4875.0
# 4                                                 NaN   NaN    250   4625.0
# ..                                                ...   ...    ...      ...
# 437                                               NaN   250    NaN    250.0
# 438                                               NaN   666    NaN    916.0
# 439                                               NaN  2000    NaN   2916.0
# 441                                               NaN   NaN    NaN      NaN
# 442  Created by QB Online to link credits to charges.     0    NaN      0.0
#
# [387 rows x 10 columns]

# %%
ledger_df[
(ledger_df['Account'] == 'Landscaping Services') &
(ledger_df['SubAccount'] == 'Fountains and Garden Lighting')
]
# Out:
#                   Account                     SubAccount Date  \
# 273  Landscaping Services  Fountains and Garden Lighting  NaN
#
#     Transaction Type  Num Name Memo/Description Debit Credit  Balance
# 273              NaN  NaN  NaN              NaN   NaN    NaN      NaN

# %% [markdown]
# Or re-sort the table by any of its columns:

# %%
ledger_df.sort_values('Credit', ascending=False).head(10)
# Out:
#                        Account SubAccount        Date      Transaction Type  \
# 222              Notes Payable        NaN  01/01/2021         Journal Entry
# 226     Opening Balance Equity        NaN  12/19/2020         Journal Entry
# 225     Opening Balance Equity        NaN  08/21/2020               Deposit
# 219               Loan Payable        NaN  01/01/2021         Journal Entry
# 162     Accounts Payable (A/P)        NaN  12/28/2020                  Bill
# 28                    Checking        NaN  01/01/2021  Bill Payment (Check)
# 293       Landscaping Services        NaN  12/23/2020               Invoice
# 97   Accounts Receivable (A/R)        NaN  01/04/2021               Payment
# 157     Accounts Payable (A/P)        NaN  12/19/2020                  Bill
# 22                    Checking        NaN  12/28/2020  Bill Payment (Check)
#
#       Num                        Name Memo/Description Debit   Credit  \
# 222   NaN                         NaN  Opening Balance   NaN    25000
# 226   NaN                         NaN  Opening Balance   NaN    13495
# 225   NaN                         NaN              NaN   NaN     5000
# 219   NaN                         NaN  Opening Balance   NaN     4000
# 162   NaN  Brosnahan Insurance Agency  Opening Balance   NaN     2000
# 28      1  Brosnahan Insurance Agency              NaN   NaN     2000
# 293  1004                   Cool Cars              Sod   NaN     1750
# 97    NaN                   Cool Cars              NaN   NaN  1675.52
# 157   NaN             Hall Properties              NaN   NaN      900
# 22     11             Hall Properties              NaN   NaN      900
#
#       Balance
# 222  25000.00
# 226  18495.00
# 225   5000.00
# 219   4000.00
# 162   4213.62
# 28    1852.51
# 293   2006.89
# 97    4967.24
# 157   1157.03
# 22    3058.61

# %% [markdown]
# Or compute summary values for any account in the table:

# %%
ledger_df[ledger_df['Account'] == 'Utilities']
# Out:
#        Account        SubAccount        Date Transaction Type  Num  \
# 426  Utilities               NaN         NaN              NaN  NaN
# 427  Utilities  Gas and Electric         NaN              NaN  NaN
# 428  Utilities               NaN  11/20/2020             Bill  NaN
# 429  Utilities               NaN  12/19/2020             Bill  NaN
# 431  Utilities         Telephone         NaN              NaN  NaN
# 432  Utilities               NaN  11/19/2020             Bill  NaN
# 433  Utilities               NaN  12/19/2020             Bill  NaN
#
#               Name    Memo/Description   Debit Credit  Balance
# 426            NaN                 NaN     NaN    NaN      NaN
# 427            NaN                 NaN     NaN    NaN      NaN
# 428           PG&E                 NaN   86.44    NaN    86.44
# 429           PG&E                 NaN  114.09    NaN   200.53
# 431            NaN                 NaN     NaN    NaN      NaN
# 432  Cal Telephone                 NaN    56.5    NaN    56.50
# 433  Cal Telephone  Monthly Phone Bill   74.36    NaN   130.86

# %%
ledger_df[ledger_df['Account'] == 'Utilities']['Debit']
# Out:
# 426       NaN
# 427       NaN
# 428     86.44
# 429    114.09
# 431       NaN
# 432      56.5
# 433     74.36
# Name: Debit, dtype: object

# %%
ledger_df[ledger_df['Account'] == 'Utilities']['Debit'].sum()
# Out:
# 331.39

# %% [markdown]
# We can also save the scrubbed GL back to an Excel file that is much easier to work with by running:

# %%
ledger_df.to_excel('data/Clean QuickBooks GL.xlsx', index=False)

# %%
ledger_df.head()
# Out:
#     Account SubAccount        Date      Transaction Type   Num  \
# 0  Checking        NaN         NaN                   NaN   NaN
# 1  Checking        NaN  08/21/2020               Deposit   NaN
# 2  Checking        NaN  10/02/2020  Bill Payment (Check)    10
# 3  Checking        NaN  10/10/2020               Payment  1053
# 4  Checking        NaN  10/24/2020               Expense    12
#
#                      Name Memo/Description Debit Credit  Balance
# 0                     NaN              NaN   NaN    NaN      NaN
# 1                     NaN  Opening Balance  5000    NaN   5000.0
# 2  Robertson & Associates              NaN   NaN    300   4700.0
# 3    Bill's Windsurf Shop              NaN   175    NaN   4875.0
# 4  Robertson & Associates              NaN   NaN    250   4625.0

# %%
ledger_df = pd.read_excel('data/QuickBooks GL.xlsx', skiprows=4)  # Read the Excel file and skip the first 4 rows to clean up the header

ledger_df = ledger_df.dropna(how='all', axis='columns')                             # Drop columns that have all missing (NaN) values
ledger_df = ledger_df.dropna(how='all', axis='rows')                                # Drop rows that have all missing (NaN) values
ledger_df = ledger_df.rename(columns={'Acct': 'Account', 'SubAcct': 'SubAccount'})  # Rename columns for clarity
ledger_df['Account'] = ledger_df['Account'].ffill()                                 # Forward fill missing values in the 'Account' column
 
# Function to check if a row contains a subtotal based on the presence of 'Total' in the name
def is_subtotal(name):  
    return pd.notna(name) and 'Total' in name

valid_accounts = [name for name in ledger_df['Account'].unique()        # Get valid 'Account' names excluding those containing 'Total'
    if not is_subtotal(name)]
valid_subaccounts = [name for name in ledger_df['SubAccount'].unique()  # Get valid 'SubAccount' names excluding those containing 'Total'
    if not is_subtotal(name)]

ledger_df = ledger_df[ledger_df['Account'].isin(valid_accounts)]        # Filter the DataFrame to keep rows with valid 'Account' values
ledger_df = ledger_df[ledger_df['SubAccount'].isin(valid_subaccounts)]  # Filter the DataFrame to keep rows with valid 'SubAccount' values

# Ensure 'SubAccount' is of a compatible data type (e.g., string or object)
ledger_df['SubAccount'] = ledger_df['SubAccount'].astype(str)   # Convert to string type before applying ffill

# Now apply forward fill (ffill) in a loop
for account in ledger_df['Account'].unique():
    ledger_df.loc[ledger_df['Account'] == account, 'SubAccount'] = ledger_df.loc[
        ledger_df['Account'] == account, 'SubAccount'].ffill()  # Apply forward fill (ffill) to 'SubAccount' for the current 'Account'

# Optionally, infer the object dtype after filling
ledger_df = ledger_df.infer_objects()                           # Ensure the columns have the correct dtype after the operation

ledger_df = ledger_df.dropna(subset=ledger_df.columns[2:], how='all')   # Drop rows where all columns from the 3rd column onward are NaN

ledger_df.head()
# Out:
#     Account SubAccount        Date      Transaction Type   Num  \
# 1  Checking        nan  08/21/2020               Deposit   NaN
# 2  Checking        nan  10/02/2020  Bill Payment (Check)    10
# 3  Checking        nan  10/10/2020               Payment  1053
# 4  Checking        nan  10/24/2020               Expense    12
# 5  Checking        nan  11/15/2020                 Check     4
#
#                      Name Memo/Description   Debit  Credit  Balance
# 1                     NaN  Opening Balance  5000.0     NaN  5000.00
# 2  Robertson & Associates              NaN     NaN  300.00  4700.00
# 3    Bill's Windsurf Shop              NaN   175.0     NaN  4875.00
# 4  Robertson & Associates              NaN     NaN  250.00  4625.00
# 5      Chin's Gas and Oil              NaN     NaN   54.55  4570.45
